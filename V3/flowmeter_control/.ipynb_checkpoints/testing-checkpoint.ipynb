# %% [markdown]
# # Insert some random values in the flowmeter table

# %%
import pandas as pd
import sqlalchemy as sql
import numpy as np
import datetime
import pymysql
import matplotlib.pyplot as plt
import time
# %matplotlib inline

host="twofast-rpi3-0"  # your host
user='reader' # username
pw='heiko'  # password
db="NG_twofast_DB" # name of the database
connect_string = 'mysql+pymysql://%(user)s:%(pw)s@%(host)s:3306/%(db)s'% {"user": user, "pw": pw, "host": host, "db": db}
sql_engine = sql.create_engine(connect_string)

def insert_to_db(sql_engine, rnd):
    sql_engine.execute("INSERT INTO flow_meter_readout_live (read_voltage) VALUES (%(rnd)s)" % {"rnd":rnd})

def read_db(sql_engine, table):
    """
    Reads the last 10 entries of the two temperatures and returns it in a dataframe
    """
    query = "SELECT * FROM %(tableName)s ORDER BY id" % {"tableName": table}
    df = pd.read_sql(query, sql_engine)
    return df

while True:
    rnd = np.random.rand() * 5
    insert_to_db(sql_engine, rnd)
    print(f'Inserting: {rnd}')
    time.sleep(2)

# %% [markdown]
# # Insert some random values in the power and frequency table

# %%
import pandas as pd
import sqlalchemy as sql
import numpy as np
import datetime
import pymysql
import matplotlib.pyplot as plt
import time
# %matplotlib inline

host="twofast-rpi3-0"  # your host
user='reader' # username
pw='heiko'  # password
db="NG_twofast_DB" # name of the database
connect_string = 'mysql+pymysql://%(user)s:%(pw)s@%(host)s:3306/%(db)s'% {"user": user, "pw": pw, "host": host, "db": db}
sql_engine = sql.create_engine(connect_string)

def insert_to_db(sql_engine, FP, RP, power_setpoint):
    sql_engine.execute("INSERT INTO microwave_generator_power (FP, RP, power_setpoint) VALUES (%(FP)s, %(RP)s, %(power_setpoint)s)" % {"FP":FP, "RP":RP, "power_setpoint": power_setpoint})
def insert_to_db_frequ(sql_engine, freq, freq_setpoint):
    sql_engine.execute("INSERT INTO microwave_generator_frequency (frequency, frequency_setpoint) VALUES (%(freq)s, %(freq_setpoint)s)" % {"freq":freq, "freq_setpoint": freq_setpoint})

while True:
    FP = 10 + np.random.rand() * 190.0
    RP = np.random.rand() * 0.2 * FP
    rnd = np.random.rand()
    if rnd > 0.6:
        FP = 0
    power_setpoint = 200.0
    insert_to_db(sql_engine, FP, RP, power_setpoint)
    freq = 2400 + np.random.rand() * 100
    freq_setpoint = 2459
    insert_to_db_frequ(sql_engine, freq, freq_setpoint)
    print(f'Inserting: {FP}, {RP}, {rnd}')
    time.sleep(2)
# Out:
# Inserting: 55.95399489588848, 4.879018327128415, 0.4763734878367992
# Inserting: 0, 23.130603435753283, 0.6078159434836026
# Inserting: 126.3996221899905, 7.491993477575446, 0.4025393714724784
# Inserting: 0, 20.371519571999723, 0.7791474650901997
# Inserting: 53.04147957587791, 3.1483028336255128, 0.5797083601788768
# Inserting: 0, 17.553511311364403, 0.7262844609019169
# Inserting: 47.112391700675495, 9.270222074536788, 0.4361163293791763
# Inserting: 98.09318499795235, 6.083478728959118, 0.03871694836255479
# Inserting: 95.59185300845944, 14.61036367625291, 0.4498980681586696
# Inserting: 0, 0.2744208141792301, 0.7465078796747442
# Inserting: 165.5933357853146, 30.783352767219775, 0.5632730121378181
# Inserting: 0, 7.416000256627491, 0.6174981837627653
# Inserting: 16.295082495483612, 2.610456575952993, 0.23668933293452254
# Inserting: 196.21817521248042, 17.33716569963784, 0.2595492104944854
# Inserting: 62.06846517152428, 4.35403179282521, 0.060745926643114845
# Inserting: 0, 0.01265187181218255, 0.854154750979043
# Inserting: 117.36680651220367, 18.952785174386985, 0.30532939184127217
# Inserting: 54.11529654755692, 10.01333186088225, 0.35751713971490284
# Inserting: 165.30202336583295, 4.962785184329283, 0.04364905670690156
# Inserting: 119.62466322594791, 3.9276328701337, 0.5345420403735277
# Inserting: 0, 3.302202615466909, 0.647790756962338
# Inserting: 0, 24.0584396975413, 0.9022973066558609
# Inserting: 0, 1.3208552401564082, 0.6665495545588458
# Inserting: 61.649094654392194, 2.930249469628471, 0.4218179846737191
# Inserting: 0, 4.68547937929473, 0.9005699534219043
# Inserting: 52.329299073681135, 6.92002246350137, 0.30886847345910906
# Inserting: 126.39765248005729, 10.737925614538858, 0.26891420658235643
# Inserting: 154.9132413561124, 6.584024650875214, 0.20319348094466672
# Inserting: 44.075082638337626, 1.744544335337191, 0.015551897355232325
# Inserting: 20.797448036510517, 2.8769463837446736, 0.25369296380620665
# Inserting: 0, 15.459614318410747, 0.8400046859170561
# Inserting: 43.742341784242434, 2.4980494772041126, 0.21864461519831024
# Inserting: 23.514732382261997, 3.605832380873221, 0.17461878855118695
# Inserting: 52.27500605419658, 9.851864190825667, 0.35469124234609706
# Inserting: 25.93028926862334, 0.4319466820139358, 0.5518720363677534
# Inserting: 120.96897952555511, 14.155229619943539, 0.1468144724750008
# Inserting: 36.55611266013337, 4.61364128428414, 0.08499181059284455
# Inserting: 0, 6.076522513637212, 0.8201561166707175
# Inserting: 0, 1.170740172661983, 0.9636531379239163
# Inserting: 53.78578362795754, 10.073954143623915, 0.3763293620814345
# Inserting: 148.5835870026024, 24.449510048446562, 0.06322964017542565
# Inserting: 0, 8.088514190695633, 0.7589680280529789
# Inserting: 0, 1.8153598558782456, 0.8232891644442513
# Inserting: 94.41388958626194, 5.4076735711491475, 0.52109171773095
# Inserting: 0, 15.264736098228695, 0.9194691495070885
# Inserting: 115.36600885806172, 22.649754075364168, 0.17239507886807548
# Inserting: 190.6517481854316, 24.220420247806235, 0.03331968232897109
# Inserting: 0, 16.445795770860784, 0.8160964219393371
# Inserting: 0, 16.059689694584634, 0.6693883181091023
# Inserting: 98.42012957421694, 8.036127223721168, 0.36869744654346615
# Inserting: 47.66377328455295, 6.70546217946631, 0.3033580720449236
# Inserting: 0, 18.17594237755298, 0.660684375973152
# Inserting: 0, 5.818282495300544, 0.8896257113250736
# Inserting: 185.323398085918, 35.04955571665752, 0.23263660125216412
# Inserting: 0, 10.774104295953515, 0.9713416162591086
# Inserting: 67.97874138184874, 1.1243413270891318, 0.2774609665449621
# Inserting: 135.35881407922088, 26.427587779889446, 0.36677804846007656
# Inserting: 0, 0.10119518917988052, 0.910884784340154
# Inserting: 122.14374455831367, 23.09747253159416, 0.06181384653957567
# Inserting: 188.54383924634593, 20.292322757101267, 0.22993324572771712
# Inserting: 0, 18.205130967312552, 0.8465706687046437
# Inserting: 15.360192226326602, 2.947000074696635, 0.013788685103173548
# Inserting: 103.02009252582097, 6.4081839028148995, 0.2923379864417005
# Inserting: 0, 24.06887947888828, 0.8600772012028906
# Inserting: 60.10155913491115, 5.942341288894637, 0.4666755471915236
# Inserting: 110.76241486126136, 0.2294317002768357, 0.5324492438180717
# Inserting: 0, 2.947103879623035, 0.620073186216091
# Inserting: 41.53284641138293, 8.217025331472843, 0.4354062955731034
# Inserting: 0, 5.251314103808576, 0.9306642734761116
# Inserting: 0, 2.7462925755729177, 0.8580635162708237
# Inserting: 10.366216585517993, 1.5514750373169108, 0.17196022406007572
# Inserting: 0, 2.8834358859054543, 0.9364067639555104
# Inserting: 29.049270918125565, 0.8638738286362221, 0.08948322774273954
# Inserting: 182.42163104145592, 27.62538883717872, 0.416295687572942
# Inserting: 177.10080649995282, 26.355424778077843, 0.32372050983438894
# Inserting: 192.19927230787465, 19.614930812507954, 0.4709133995273378
# Inserting: 111.13961296999753, 2.3436487479671335, 0.15015820559038517
# Inserting: 171.6864599302916, 11.303185636866615, 0.014388131484490474
# Inserting: 0, 9.4530927659256, 0.8025031309083881
# Inserting: 167.12737029075353, 18.211896875183733, 0.13118999094581207
# Inserting: 0, 19.955776355158097, 0.7931532509764615
# Inserting: 42.385019115255645, 3.7551896480424665, 0.023358417333061543
# Inserting: 0, 17.71714403611862, 0.9363590107980458
# Inserting: 0, 6.122552818837279, 0.760144186710369
# Inserting: 163.79327634952168, 1.1819589540074977, 0.31337358098784707
# Inserting: 0, 6.598006670512989, 0.7060790525696325
# Inserting: 181.5831353229485, 9.265675043732708, 0.5970921819964559
# Inserting: 80.2050509652382, 14.104079520475008, 0.3215155865250322
# Inserting: 0, 5.176710728114022, 0.7586495324927423
# Inserting: 74.49030642015921, 4.431058911278361, 0.06799092037012189
# Inserting: 0, 17.05938748601018, 0.7791490710670104
# Inserting: 53.379170921615334, 2.33327704476095, 0.5286259779007255
# Inserting: 0, 7.39372651187074, 0.7279178052315443
# Inserting: 0, 0.4792086535157987, 0.6848739213821836
# Inserting: 45.51964306527067, 8.760614376151103, 0.2952976075137552
# Inserting: 101.34725594696361, 0.5711205279573619, 0.3033601313818115
# Inserting: 0, 20.404271962463756, 0.9610827999040913
# Inserting: 0, 35.27315958628812, 0.6738097640898564
# Inserting: 40.34348113419117, 2.8158479246286343, 0.09751152114428496
# Inserting: 103.09084053871074, 10.797338023494367, 0.48293362719814004
# Inserting: 0, 5.757667314174483, 0.6807508024625929
# Inserting: 0, 6.4379346006702995, 0.9391299214095977
# Inserting: 46.87848201203769, 7.904740320682224, 0.19969288307666822
# Inserting: 94.38790011696102, 3.5067187946014213, 0.5067047118266031
# Inserting: 0, 14.760365024872684, 0.6310447953872169
# Inserting: 0, 18.07269410236381, 0.729693506462609
# Inserting: 173.9475723722653, 31.46622307684838, 0.526487673881397
# Inserting: 103.39365339920707, 3.0646510885875364, 0.2309718711381784
# Inserting: 0, 3.1468371119652416, 0.7781233070300158
# Inserting: 171.57332962821906, 16.87226283122403, 0.11990962808422556
# Inserting: 67.84656050141281, 2.8449351097555002, 0.21071036641028018
# Inserting: 189.10657201639611, 14.136013011454946, 0.4599457498390713
# Inserting: 97.3076997268106, 6.69699418215014, 0.44786105625766304
# Inserting: 0, 5.013248112329259, 0.6728591276556313
# Inserting: 163.16464301554515, 12.654138047434833, 0.0004148832554957682
# Inserting: 0, 9.96551048841229, 0.9243933103806102
# Inserting: 0, 19.490640542121117, 0.7239829882442282
# Inserting: 0, 5.779108748633906, 0.8777457998159318
# Inserting: 14.687418546988816, 1.2826999091051374, 0.5761154761589794
# Inserting: 51.08637214515572, 2.709135539852706, 0.024910665259494702
# Inserting: 83.55144938626958, 14.505606210765555, 0.11847985035970843
# Inserting: 117.85842009237608, 8.935937399118293, 0.01644833512900923
# Inserting: 0, 2.6602014847462923, 0.7647088215898895
# Inserting: 0, 18.66257106386612, 0.8021475253481152
# Inserting: 0, 9.238231573074247, 0.6875922372200879
# Inserting: 165.67496147513577, 9.378965862010403, 0.13471358434364245
# Inserting: 0, 10.031881332259617, 0.9945846063641199
# Inserting: 162.19155524006075, 15.137320968296745, 0.10299269180151094
# Inserting: 189.41913970584164, 0.7058812187401341, 0.330088706139127
# Inserting: 0, 15.519630801197058, 0.6183568837908647
# Inserting: 0, 30.04207321662939, 0.8319003307021933
# Inserting: 0, 13.810654117633238, 0.8887103197011476
# Inserting: 159.97118562203985, 28.005507808198253, 0.028166813892570475
# Inserting: 143.7382479144392, 12.03873434179471, 0.13025346722991604
# Inserting: 33.67523231006878, 6.573968494684026, 0.2567209040926506
# Inserting: 88.80034033333854, 8.851941879970171, 0.433215877317058
# Inserting: 0, 2.1931547319878635, 0.6313042940201747
# Inserting: 0, 5.345657010903088, 0.7074791242749735
# Inserting: 136.91187373730446, 20.784888414984184, 0.5865687207096147
# Inserting: 0, 1.5798260585312764, 0.606072212966038
# Inserting: 0, 13.449831812236434, 0.7396685320317474
# Inserting: 110.65459056654532, 1.029305512502302, 0.42593569134474973
# Inserting: 91.97875407496903, 13.44374613591892, 0.06298851176909814
# Inserting: 137.4730798649208, 11.17908061119584, 0.17153506080792635
# Inserting: 33.499404718276296, 1.926045033865062, 0.1576991537958824
# Inserting: 102.3304312181406, 1.2603697699228034, 0.0443708909473981
# Inserting: 0, 0.44146405371678477, 0.7722300060367561
# Inserting: 0, 4.877225192597914, 0.8426674847377863
# Inserting: 178.53913703589905, 6.617805936426074, 0.03530687256260556
# Inserting: 145.2558906283595, 8.019472101012173, 0.018630352901664815
# Inserting: 127.01273643668105, 12.814231524991468, 0.5999111823959395
# Inserting: 0, 3.5419609143333304, 0.9665201690260397
# Inserting: 0, 16.3449787703207, 0.8503785709673789
# Inserting: 0, 2.611206140021805, 0.777551013417539
# Inserting: 97.59327947086823, 3.142747323876558, 0.5802084683029697
# Inserting: 38.00759685287905, 2.9531047382747633, 0.33141530391579066
# Inserting: 178.032368213285, 7.793167601634311, 0.43217893530402485
# Inserting: 0, 22.85366510911301, 0.804600728459676
# Inserting: 100.09871686885643, 7.256668792024573, 0.011656245189401782
# Inserting: 11.253044823925524, 1.6592586511280187, 0.09605931372122911
# Inserting: 89.8998692949142, 9.588273112448933, 0.07981472262394285
# Inserting: 0, 6.607453829269126, 0.9616851253300115
# Inserting: 158.0011259177966, 29.79437849295976, 0.4182136877912861
# Inserting: 75.97468352562602, 2.638287148423646, 0.08983018002880361
# Inserting: 72.25370683587303, 1.8866946083283649, 0.012617675510956383
# Inserting: 86.853009145765, 13.543313473817353, 0.4677512792024
# Inserting: 129.27282562553714, 9.265344669953322, 0.030342581355501497
# Inserting: 68.64560547332889, 1.5446167855010222, 0.408681831415988
# Inserting: 135.01166378126803, 21.88663079440592, 0.3113873782265545
# Inserting: 0, 7.832559269922245, 0.9209343824697036
# Inserting: 43.55131243422261, 7.410040869544177, 0.530739727365394
# Inserting: 0, 5.442267633480834, 0.9528325984292971
# Inserting: 0, 23.83483442231843, 0.7538854539762239
# Inserting: 123.55507055007861, 6.313659374744483, 0.5377877165971257
# Inserting: 0, 16.9690999027936, 0.9808158629916307
# Inserting: 119.08210018130518, 2.128697432514539, 0.08825345822928832
# Inserting: 37.81261870966569, 4.008326153059169, 0.5847941863698666
# Inserting: 189.67886945502363, 11.318361600050764, 0.45946687126000996
# Inserting: 106.04190969947572, 10.05317065121884, 0.0787188263592149
# Inserting: 36.319538592759315, 1.266525881578084, 0.023904956158104174
# Inserting: 0, 30.799014648144393, 0.9430121441201805
# Inserting: 182.73434167439896, 7.94202632402083, 0.5852221154591036
# Inserting: 0, 14.116334655427444, 0.9051892702805274
# Inserting: 0, 3.766055250756484, 0.6508688401498487
# Inserting: 0, 10.854132207091029, 0.6803002511072436
# Inserting: 103.82125586366544, 2.5729231503219596, 0.3718962062822694
# Inserting: 0, 23.21267598313157, 0.6694541669934524
# Inserting: 0, 17.85664882211928, 0.7405029275141408
# Inserting: 28.479163980446753, 1.212084514137014, 0.2945445984160602
# Inserting: 0, 4.490079184150461, 0.8729405396980738
# Inserting: 182.10793440704307, 2.6045727703108765, 0.35630521372193824
# Inserting: 187.2282137706995, 12.959836187257853, 0.034848630947467596
# Inserting: 36.310959042774456, 2.6178980221223664, 0.1191351609714223
# Inserting: 0, 5.91735383138224, 0.8940676144059898
# Inserting: 0, 19.943310775799972, 0.6388774323462111
# Inserting: 0, 20.292900225874117, 0.6905156188925146
# Inserting: 173.46981415421473, 30.92517174429182, 0.06546039378269664
# Inserting: 0, 17.747305285671334, 0.913934945978552
# Inserting: 143.1546915702585, 14.441900632442907, 0.5106318001120611
# Inserting: 0, 0.46582728612613905, 0.6034687636212384
# Inserting: 69.30791833698481, 2.422511161094, 0.3915693570535621
# Inserting: 0, 3.304556194834331, 0.8328767625404598
# Inserting: 92.18825220207553, 5.636656951555519, 0.5765727639284051
# Inserting: 146.85795477569349, 18.164649128534993, 0.5221228005637235
# Inserting: 128.8171274124488, 16.190324113315512, 0.387882759333132
# Inserting: 0, 0.9071126632069387, 0.7856934561144379
# Inserting: 0, 0.7853253517642967, 0.667529209180741
# Inserting: 53.737197217670804, 10.482113628761464, 0.2558143358925188
# Inserting: 113.02820324157378, 19.390935414455512, 0.09729719838785533
# Inserting: 147.86845327691438, 15.084028689974682, 0.5042017895811045
# Inserting: 0, 25.398838364152326, 0.6130564658868624
# Inserting: 0, 4.737596528177422, 0.8147164620368051
# Inserting: 162.3013258893005, 21.321509717977086, 0.22007666366560452
# Inserting: 46.66018847446986, 0.9140766929712821, 0.04308827812144567
# Inserting: 114.05200347514156, 3.563326572746348, 0.17836224198946238
# Inserting: 111.96037307701029, 15.187184364732309, 0.5854372233682127
# Inserting: 177.69366526204098, 27.800042785287065, 0.294962934076478
# Inserting: 0, 3.5954439913708742, 0.930973232005685
# Inserting: 96.14350060334458, 17.904783437924607, 0.27739682964897916
# Inserting: 54.587833298281886, 7.196984205331066, 0.2675608081890154
# Inserting: 0, 1.645043633563506, 0.791304278133222
# Inserting: 182.650592425611, 10.168367721869977, 0.10339139187155655
# Inserting: 0, 2.4192974868032464, 0.6313911541981962
# Inserting: 0, 2.312288341132241, 0.6729417411253067
# Inserting: 75.22138050148827, 8.024219304225571, 0.1491331990963708
# Inserting: 0, 1.686158496146553, 0.7921404206286116
# Inserting: 0, 1.1115484343295212, 0.6917901511025344
# Inserting: 13.40047929982535, 0.8320316834979652, 0.12249472275010365
# Inserting: 0, 3.9953330262543627, 0.6331861854679892
# Inserting: 95.79237226961882, 9.51726967101535, 0.269138597091794
# Inserting: 27.817790216466012, 3.2405765322967524, 0.5681834724388009
# Inserting: 46.77815601072568, 8.669513109180548, 0.049052602540488266
# Inserting: 0, 12.368078083638235, 0.6634998720123086
# Inserting: 195.44629448651213, 3.349470236106616, 0.18783330318503622
# Inserting: 0, 11.714013333401162, 0.6783725279895363
# Inserting: 77.46964652028153, 6.637295930245992, 0.10347142475178162
# Inserting: 197.45673816170688, 34.338305361627974, 0.020033285636106846
# Inserting: 0, 10.139761398429673, 0.8847707520477619
# Inserting: 46.76875078202296, 7.33955596694493, 0.09252579043059095
# Inserting: 113.62227041700899, 14.672518430464732, 0.4683580465830828
# Inserting: 73.57768050068546, 4.6227707193070025, 0.5328979428503379
# Inserting: 0, 2.2644425251289926, 0.7189707521242082
# Inserting: 152.02251451260975, 6.695090007896317, 0.2709451915018939
# Inserting: 33.02113904386964, 6.111400980204169, 0.5478307951471363
# Inserting: 195.67967425587682, 30.062118418820155, 0.10024837187398972
# Inserting: 0, 5.979618140744819, 0.9795802183620841
# Inserting: 0, 17.774706224805655, 0.9554065985966699
# Inserting: 69.81140808387822, 11.50607033999796, 0.2970226630334688
# Inserting: 15.041066166327202, 3.001525732139636, 0.4054488369048843
# Inserting: 162.10868809427657, 19.570375566394855, 0.023022077897515647
# Inserting: 112.45006095094217, 14.550483943370029, 0.1963515078298973
# Inserting: 0, 3.1015721483134944, 0.9296329860776258
# Inserting: 0, 3.0727773564393206, 0.7054070950542709
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-33abee6ad987> in <module>
#      27     insert_to_db(sql_engine, FP, RP, power_setpoint)
#      28     print(f'Inserting: {FP}, {RP}, {rnd}')
# ---> 29     time.sleep(2)
#
# KeyboardInterrupt:
